# %%
import sys, tweepy
import pandas as pd

# %%
api_key = "vhpYxpHap3JT2knXp3hyiUrJs"
api_secret_key = "TVsN2J4ZrHEHwrPlhtihuBWolXWibF7878exrK9hQ7zQywq9Dp"

# %%
bearer_token = "AAAAAAAAAAAAAAAAAAAAAGe7JQEAAAAAxY1bj4PHloQmCG6MXMGiKVoUlyM%3DwLgIydkepC59w4RJ54ghNEuznPUDQkC2yhwr1deQCwwQY02V5L"
access_token = "1324015519708684289-HBCPYHbS8HPZ0Rq4YY5ZarJvOmei8I"
access_token_secret = "6NO0tM6dMoapFyCLLFt2OaQJ1xmvO1sUoUmrPJdmmquXx"

# %%
auth = tweepy.OAuthHandler(api_key, api_secret_key)
auth.set_access_token(access_token, access_token_secret)

# %%
try:
    redirect_url = auth.get_authorization_url()
except tweepy.TweepError:
    print('Error! Failed to get request token.')

# %%
api = tweepy.API(auth)

# %%
tweets = pd.read_table('2020-03-22_clean-dataset.tsv')

# %%
tweets.shape
# Out:
# (779692, 3)

# %%
corpus = tweets.tweet_id

# %%
for twitter_id in corpus:
    try:
        tweetFetched = api.get_status(twitter_id)

        if tweetFetched.lang == 'en':
            print(tweetFetched.text)
    except:
        continue
# Out:
# US 🇺🇸 https://t.co/5NpOWeljQf
# FaceTiming and Hungry Hippos: How the elderly are being supported and entertained during coronavirus outbreak | Wal… https://t.co/hPy4MG2MjT
# Looks like the government, once more, has ignored people on Disability Support Pensioner. #coronavirus… https://t.co/TrfUAJEWQu
# Coronavirus updates: Coronavirus cases top 300,000 worldwide...it amazes me we live in the 21st century and stores… https://t.co/mx2yxnYtmZ
# India has finally given private labs a go-ahead to run #COVID19 tests. Experts say expect India’s confirmed cases t… https://t.co/vUrIkbp3np
# @IndoPac_Info Please stop retweeting this now !  Take it from the professor      ! https://t.co/GVfcq3ne7N
# DOJ Wants to Suspend Constitutional Rights for Coronavirus Emergency – Rolling Stone https://t.co/ErCmQF7wAf
# Don’t take that Coronavirus vaccine it’s gone be the start of the zombie apocalypse
# Glad you're enjoying the book and finding it helpful. https://t.co/KCgo8Pv7jp
# ...

# %%
tweetFetched = api.get_status(twitter_id)
print(tweetFetched.text)
# Out:
# Twitter is out of control, made possible through the government gift of Section 230!

# %%
tweetFetched.lang
# Out:
# 'en'

# %%
api.statuses_lookup(list(corpus[0:199].values))
# Out:
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-16-7f21f751f8c5> in <module>
# ----> 1 api.statuses_lookup(list(corpus[0:199].values))
#
# ~/opt/anaconda3/envs/social_graphs/lib/python3.7/site-packages/tweepy/api.py in statuses_lookup(self, id_, *args, **kwargs)
#     115                            'include_ext_alt_text', 'include_card_uri'],
#     116             require_auth=True
# --> 117         )(list_to_csv(id_), *args, **kwargs)
#     118
#     119     @property
#
# ~/opt/anaconda3/envs/social_graphs/lib/python3.7/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     250                 return method
#     251             else:
# --> 252                 return method.execute()
#     253         finally:
#     254             method.session.close()
#
# ~/opt/anaconda3/envs/social_graphs/lib/python3.7/site-packages/tweepy/binder.py in execute(self)
# ...

# %%
userID = "realDonaldTrump"

# %%
# Authorize our Twitter credentials
tweets = api.user_timeline(screen_name=userID, 
                           # 200 is the maximum allowed count
                           count=200,
                           include_rts = False,
                           # Necessary to keep full_text 
                           # otherwise only the first 140 words are extracted
                           tweet_mode = 'extended'
                           )

# %%
for info in tweets[:3]:
     print("ID: {}".format(info.id))
     print(info.created_at)
     print(info.full_text)
     print("\n")
# Out:
# ID: 1324613375213621248
# 2020-11-06 07:23:33
# Twitter is out of control, made possible through the government gift of Section 230!
#
#
# ID: 1324613181466173440
# 2020-11-06 07:22:47
# I easily WIN the Presidency of the United States with LEGAL VOTES CAST. The OBSERVERS were not allowed, in any way, shape, or form, to do their job and therefore, votes accepted during this period must be determined to be ILLEGAL VOTES. U.S. Supreme Court should decide!
#
#
# ID: 1324612560646262785
# 2020-11-06 07:20:19
# So now the Democrats are working to gain control of the U.S. Senate through their actions on John James, David Perdue, and more. Would End the Filibuster, “Life”, 2A, and would Pack and Rotate the Court. Presidency becomes even more important. We will win!

# %%
info.lang
# Out:
# 'en'

# %%
info.place

# %%
info.text + " | " + info.place.name if info.place else "Undefined place"
# Out:
# 'Undefined place'

# %%
info
